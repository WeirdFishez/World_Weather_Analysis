# %%
# Dependencies
import json
import requests
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from citipy import citipy
from datetime import datetime
import time
load_dotenv()
api_key = os.getenv("OpenWeather_API_KEY")

# %%
# Create a list for holding the cities.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 596

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

city_url
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | srednekolymsk
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | lasa
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | los andes
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | sioux lookout
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | vestmannaeyjar
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | bilma
# Processing Record 16 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | kupang
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | vicuna
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 1 | nurota
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | ankang
# Processing Record 30 of Set 1 | kuusamo
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | san fernando
# Processing Record 33 of Set 1 | odienne
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | vao
# Processing Record 37 of Set 1 | flinders
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | avera
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | shache
# Processing Record 44 of Set 1 | uni
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | olafsvik
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | port pirie
# Processing Record 1 of Set 2 | palora
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | kieta
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | cabo san lucas
# Processing Record 6 of Set 2 | santa catalina
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | goderich
# Processing Record 9 of Set 2 | hibbing
# Processing Record 10 of Set 2 | henties bay
# Processing Record 11 of Set 2 | tezu
# Processing Record 12 of Set 2 | linqing
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | muros
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | lavrentiya
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | estacion coahuila
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | blagoyevo
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | luoyang
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | la garriga
# Processing Record 35 of Set 2 | pokhara
# Processing Record 36 of Set 2 | umm ruwabah
# City not found. Skipping...
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | mumford
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | krasnoselkup
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | pisco
# Processing Record 45 of Set 2 | oussouye
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | havoysund
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | ouegoa
# Processing Record 50 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | ipixuna
# Processing Record 3 of Set 3 | arlit
# Processing Record 4 of Set 3 | limbuhan
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | progreso
# Processing Record 9 of Set 3 | auki
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | shurugwi
# Processing Record 12 of Set 3 | quatre cocos
# Processing Record 13 of Set 3 | narsaq
# Processing Record 14 of Set 3 | san pedro
# Processing Record 15 of Set 3 | saryg-sep
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | high level
# Processing Record 18 of Set 3 | iquique
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | vila franca do campo
# Processing Record 22 of Set 3 | orje
# Processing Record 23 of Set 3 | krasnyy luch
# Processing Record 24 of Set 3 | bonfim
# Processing Record 25 of Set 3 | tuatapere
# Processing Record 26 of Set 3 | pilar
# Processing Record 27 of Set 3 | asau
# Processing Record 28 of Set 3 | kamenka
# Processing Record 29 of Set 3 | nouadhibou
# Processing Record 30 of Set 3 | yerbogachen
# Processing Record 31 of Set 3 | korla
# Processing Record 32 of Set 3 | yablonovo
# Processing Record 33 of Set 3 | bontang
# Processing Record 34 of Set 3 | broken hill
# Processing Record 35 of Set 3 | baherden
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | biloela
# Processing Record 39 of Set 3 | mettlach
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | burnie
# Processing Record 46 of Set 3 | rocky mountain house
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | rocha
# Processing Record 49 of Set 3 | inongo
# Processing Record 50 of Set 3 | lahaina
# Processing Record 1 of Set 4 | manadhoo
# Processing Record 2 of Set 4 | itaituba
# Processing Record 3 of Set 4 | madras
# Processing Record 4 of Set 4 | cockburn town
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | clearwater
# Processing Record 7 of Set 4 | samoded
# Processing Record 8 of Set 4 | guatire
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | lufilufi
# Processing Record 11 of Set 4 | mosetse
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | faya
# Processing Record 15 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 16 of Set 4 | port shepstone
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | margate
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | wanning
# Processing Record 22 of Set 4 | beringovskiy
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 25 of Set 4 | miraflores
# Processing Record 26 of Set 4 | abu kamal
# Processing Record 27 of Set 4 | saint-georges
# Processing Record 28 of Set 4 | listowel
# Processing Record 29 of Set 4 | raudeberg
# Processing Record 30 of Set 4 | springdale
# Processing Record 31 of Set 4 | greenfield
# Processing Record 32 of Set 4 | labuhan
# Processing Record 33 of Set 4 | miedzyrzec podlaski
# Processing Record 34 of Set 4 | la ronge
# Processing Record 35 of Set 4 | puerto ayora
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | mporokoso
# Processing Record 38 of Set 4 | kibungo
# Processing Record 39 of Set 4 | zhanaozen
# Processing Record 40 of Set 4 | porto nacional
# Processing Record 41 of Set 4 | barrow
# Processing Record 42 of Set 4 | solano
# Processing Record 43 of Set 4 | eureka
# Processing Record 44 of Set 4 | pangnirtung
# Processing Record 45 of Set 4 | alcudia
# Processing Record 46 of Set 4 | gunnedah
# Processing Record 47 of Set 4 | oranjemund
# Processing Record 48 of Set 4 | boden
# Processing Record 49 of Set 4 | brawley
# Processing Record 50 of Set 4 | saint-honore
# Processing Record 1 of Set 5 | shenjiamen
# Processing Record 2 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 5 | fairborn
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | luganville
# Processing Record 6 of Set 5 | tura
# Processing Record 7 of Set 5 | camargo
# Processing Record 8 of Set 5 | esso
# Processing Record 9 of Set 5 | dukat
# Processing Record 10 of Set 5 | surt
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | pangai
# Processing Record 13 of Set 5 | husavik
# Processing Record 14 of Set 5 | borborema
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 5 | comodoro rivadavia
# Processing Record 18 of Set 5 | minab
# Processing Record 19 of Set 5 | georgetown
# Processing Record 20 of Set 5 | arona
# Processing Record 21 of Set 5 | sinnamary
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | yatou
# Processing Record 24 of Set 5 | san carlos de bariloche
# Processing Record 25 of Set 5 | plast
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | saint-augustin
# Processing Record 28 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 5 | lata
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | belaya gora
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | les cayes
# Processing Record 34 of Set 5 | hay river
# Processing Record 35 of Set 5 | mashhad
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | khash
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | elko
# Processing Record 40 of Set 5 | matara
# Processing Record 41 of Set 5 | mugumu
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | ayan
# Processing Record 44 of Set 5 | ayr
# Processing Record 45 of Set 5 | valparaiso
# Processing Record 46 of Set 5 | cherskiy
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | ambanja
# Processing Record 49 of Set 5 | tangshan
# Processing Record 50 of Set 5 | namatanai
# Processing Record 1 of Set 6 | saint-leu
# Processing Record 2 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 6 | port lincoln
# Processing Record 4 of Set 6 | lichinga
# Processing Record 5 of Set 6 | balkhash
# Processing Record 6 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | leh
# Processing Record 10 of Set 6 | san juan
# Processing Record 11 of Set 6 | lamar
# Processing Record 12 of Set 6 | vostok
# Processing Record 13 of Set 6 | takoradi
# Processing Record 14 of Set 6 | pangoa
# Processing Record 15 of Set 6 | saldanha
# Processing Record 16 of Set 6 | saint-philippe
# Processing Record 17 of Set 6 | axim
# Processing Record 18 of Set 6 | abha
# Processing Record 19 of Set 6 | mayo
# Processing Record 20 of Set 6 | thompson
# Processing Record 21 of Set 6 | maldonado
# Processing Record 22 of Set 6 | warrensburg
# Processing Record 23 of Set 6 | ust-kut
# Processing Record 24 of Set 6 | kapoeta
# Processing Record 25 of Set 6 | pangody
# Processing Record 26 of Set 6 | barcelona
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | komsomolskiy
# Processing Record 31 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 6 | sokna
# Processing Record 33 of Set 6 | pitimbu
# Processing Record 34 of Set 6 | montlucon
# Processing Record 35 of Set 6 | ligayan
# Processing Record 36 of Set 6 | bac lieu
# Processing Record 37 of Set 6 | suao
# City not found. Skipping...
# Processing Record 38 of Set 6 | sur
# Processing Record 39 of Set 6 | lalmohan
# Processing Record 40 of Set 6 | martil
# Processing Record 41 of Set 6 | mehamn
# Processing Record 42 of Set 6 | leirvik
# Processing Record 43 of Set 6 | tautira
# Processing Record 44 of Set 6 | zabid
# Processing Record 45 of Set 6 | obihiro
# Processing Record 46 of Set 6 | bandarbeyla
# Processing Record 47 of Set 6 | hambantota
# Processing Record 48 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 6 | saint-joseph
# Processing Record 1 of Set 7 | aquiraz
# Processing Record 2 of Set 7 | katherine
# Processing Record 3 of Set 7 | mian channun
# Processing Record 4 of Set 7 | teknaf
# Processing Record 5 of Set 7 | katobu
# Processing Record 6 of Set 7 | beloha
# Processing Record 7 of Set 7 | cowra
# Processing Record 8 of Set 7 | goure
# Processing Record 9 of Set 7 | quixeramobim
# Processing Record 10 of Set 7 | den helder
# Processing Record 11 of Set 7 | atbasar
# Processing Record 12 of Set 7 | fukue
# Processing Record 13 of Set 7 | jurm
# Processing Record 14 of Set 7 | sesheke
# Processing Record 15 of Set 7 | adre
# Processing Record 16 of Set 7 | rathdrum
# Processing Record 17 of Set 7 | chernihiv
# Processing Record 18 of Set 7 | ko samui
# Processing Record 19 of Set 7 | ketchikan
# Processing Record 20 of Set 7 | san patricio
# Processing Record 21 of Set 7 | yar-sale
# Processing Record 22 of Set 7 | cidreira
# Processing Record 23 of Set 7 | abengourou
# Processing Record 24 of Set 7 | fort pierce
# Processing Record 25 of Set 7 | ivybridge
# Processing Record 26 of Set 7 | kitob
# Processing Record 27 of Set 7 | acajutla
# Processing Record 28 of Set 7 | ust-nera
# Processing Record 29 of Set 7 | vinhedo
# Processing Record 30 of Set 7 | srandakan
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | constitucion
# Processing Record 34 of Set 7 | empalme
# Processing Record 35 of Set 7 | vadso
# Processing Record 36 of Set 7 | chapais
# Processing Record 37 of Set 7 | akyab
# Processing Record 38 of Set 7 | campbell river
# Processing Record 39 of Set 7 | pangkalanbuun
# Processing Record 40 of Set 7 | xai-xai
# Processing Record 41 of Set 7 | saint anthony
# Processing Record 42 of Set 7 | kindu
# Processing Record 43 of Set 7 | taksimo
# Processing Record 44 of Set 7 | arroyo
# Processing Record 45 of Set 7 | geraldton
# Processing Record 46 of Set 7 | thunder bay
# Processing Record 47 of Set 7 | klaksvik
# Processing Record 48 of Set 7 | isla mujeres
# Processing Record 49 of Set 7 | gore
# Processing Record 50 of Set 7 | ambovombe
# Processing Record 1 of Set 8 | duku
# Processing Record 2 of Set 8 | mount isa
# Processing Record 3 of Set 8 | mandera
# Processing Record 4 of Set 8 | burica
# City not found. Skipping...
# Processing Record 5 of Set 8 | ixtapa
# Processing Record 6 of Set 8 | sorong
# Processing Record 7 of Set 8 | manokwari
# Processing Record 8 of Set 8 | san sebastian
# Processing Record 9 of Set 8 | port hawkesbury
# Processing Record 10 of Set 8 | rosetta
# Processing Record 11 of Set 8 | beroroha
# Processing Record 12 of Set 8 | salalah
# Processing Record 13 of Set 8 | benevento
# Processing Record 14 of Set 8 | westerland
# Processing Record 15 of Set 8 | smithers
# Processing Record 16 of Set 8 | baruun-urt
# Processing Record 17 of Set 8 | maymyo
# Processing Record 18 of Set 8 | lieksa
# Processing Record 19 of Set 8 | khandagayty
# Processing Record 20 of Set 8 | portland
# Processing Record 21 of Set 8 | sao geraldo do araguaia
# Processing Record 22 of Set 8 | half moon bay
# Processing Record 23 of Set 8 | nevesinje
# Processing Record 24 of Set 8 | gulf gate estates
# Processing Record 25 of Set 8 | brodokalmak
# Processing Record 26 of Set 8 | alice springs
# Processing Record 27 of Set 8 | cururupu
# Processing Record 28 of Set 8 | gallipoli
# Processing Record 29 of Set 8 | mutata
# Processing Record 30 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 8 | murakami
# Processing Record 32 of Set 8 | fort nelson
# Processing Record 33 of Set 8 | faanui
# Processing Record 34 of Set 8 | visby
# Processing Record 35 of Set 8 | alindao
# Processing Record 36 of Set 8 | lebanon
# Processing Record 37 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 8 | naze
# Processing Record 39 of Set 8 | yining
# Processing Record 40 of Set 8 | port hardy
# Processing Record 41 of Set 8 | seguin
# Processing Record 42 of Set 8 | duncan
# Processing Record 43 of Set 8 | sisimiut
# Processing Record 44 of Set 8 | lakatoro
# Processing Record 45 of Set 8 | natal
# Processing Record 46 of Set 8 | ouadda
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | zharkent
# Processing Record 49 of Set 8 | qaqortoq
# Processing Record 50 of Set 8 | otradnoye
# Processing Record 1 of Set 9 | taltal
# Processing Record 2 of Set 9 | novoagansk
# Processing Record 3 of Set 9 | isangel
# Processing Record 4 of Set 9 | angouleme
# Processing Record 5 of Set 9 | cagsiay
# Processing Record 6 of Set 9 | segou
# Processing Record 7 of Set 9 | kautokeino
# Processing Record 8 of Set 9 | bam
# Processing Record 9 of Set 9 | xining
# Processing Record 10 of Set 9 | calvinia
# Processing Record 11 of Set 9 | maceio
# Processing Record 12 of Set 9 | stillwater
# Processing Record 13 of Set 9 | kyzyl-suu
# Processing Record 14 of Set 9 | semey
# Processing Record 15 of Set 9 | varna
# Processing Record 16 of Set 9 | sao joao da barra
# Processing Record 17 of Set 9 | nichinan
# Processing Record 18 of Set 9 | nueva guinea
# Processing Record 19 of Set 9 | ornskoldsvik
# Processing Record 20 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 21 of Set 9 | los alamos
# Processing Record 22 of Set 9 | tandil
# Processing Record 23 of Set 9 | athabasca
# Processing Record 24 of Set 9 | adrar
# Processing Record 25 of Set 9 | nautanwa
# Processing Record 26 of Set 9 | suntar
# Processing Record 27 of Set 9 | domoni
# Processing Record 28 of Set 9 | nakhon phanom
# Processing Record 29 of Set 9 | el segundo
# Processing Record 30 of Set 9 | provideniya
# Processing Record 31 of Set 9 | mairana
# Processing Record 32 of Set 9 | contamana
# Processing Record 33 of Set 9 | boca do acre
# Processing Record 34 of Set 9 | praia
# Processing Record 35 of Set 9 | olinda
# Processing Record 36 of Set 9 | adamantina
# Processing Record 37 of Set 9 | gat
# Processing Record 38 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 9 | westport
# Processing Record 40 of Set 9 | iskateley
# Processing Record 41 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 43 of Set 9 | nemuro
# Processing Record 44 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 9 | singaraja
# Processing Record 46 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 9 | orzhytsya
# Processing Record 48 of Set 9 | noboribetsu
# Processing Record 49 of Set 9 | turangi
# Processing Record 50 of Set 9 | miranda
# Processing Record 1 of Set 10 | teguldet
# Processing Record 2 of Set 10 | mocuba
# Processing Record 3 of Set 10 | smoljan
# Processing Record 4 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 10 | nome
# Processing Record 6 of Set 10 | leshukonskoye
# Processing Record 7 of Set 10 | lakes entrance
# Processing Record 8 of Set 10 | dogondoutchi
# Processing Record 9 of Set 10 | sulphur
# Processing Record 10 of Set 10 | omboue
# Processing Record 11 of Set 10 | itaporanga
# Processing Record 12 of Set 10 | mana
# Processing Record 13 of Set 10 | sabla
# Processing Record 14 of Set 10 | acari
# Processing Record 15 of Set 10 | harper
# Processing Record 16 of Set 10 | yulara
# Processing Record 17 of Set 10 | corinto
# Processing Record 18 of Set 10 | lubumbashi
# Processing Record 19 of Set 10 | acapetahua
# Processing Record 20 of Set 10 | dunedin
# Processing Record 21 of Set 10 | villa vazquez
# City not found. Skipping...
# Processing Record 22 of Set 10 | port-gentil
# Processing Record 23 of Set 10 | ust-kuyga
# Processing Record 24 of Set 10 | banda aceh
# Processing Record 25 of Set 10 | itoman
# Processing Record 26 of Set 10 | port augusta
# Processing Record 27 of Set 10 | te anau
# Processing Record 28 of Set 10 | makurdi
# Processing Record 29 of Set 10 | santa maria
# Processing Record 30 of Set 10 | lowestoft
# Processing Record 31 of Set 10 | grindavik
# Processing Record 32 of Set 10 | bethanien
# Processing Record 33 of Set 10 | waingapu
# Processing Record 34 of Set 10 | yongzhou
# Processing Record 35 of Set 10 | horta
# Processing Record 36 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 10 | sao desiderio
# Processing Record 38 of Set 10 | asekeyevo
# Processing Record 39 of Set 10 | camacupa
# Processing Record 40 of Set 10 | zlobin
# Processing Record 41 of Set 10 | tual
# Processing Record 42 of Set 10 | neryungri
# Processing Record 43 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 10 | wattegama
# Processing Record 45 of Set 10 | okhotsk
# Processing Record 46 of Set 10 | krasnaya polyana
# Processing Record 47 of Set 10 | broome
# Processing Record 48 of Set 10 | cintalapa
# Processing Record 49 of Set 10 | saint george
# Processing Record 50 of Set 10 | koumac
# Processing Record 1 of Set 11 | tabuk
# Processing Record 2 of Set 11 | araouane
# Processing Record 3 of Set 11 | kahului
# Processing Record 4 of Set 11 | veisiejai
# Processing Record 5 of Set 11 | port elizabeth
# Processing Record 6 of Set 11 | qui nhon
# Processing Record 7 of Set 11 | bay roberts
# Processing Record 8 of Set 11 | caravelas
# Processing Record 9 of Set 11 | shitanjing
# Processing Record 10 of Set 11 | vikhorevka
# Processing Record 11 of Set 11 | rio grande
# Processing Record 12 of Set 11 | kiunga
# Processing Record 13 of Set 11 | hovd
# Processing Record 14 of Set 11 | nhulunbuy
# Processing Record 15 of Set 11 | amga
# Processing Record 16 of Set 11 | japura
# Processing Record 17 of Set 11 | toila
# Processing Record 18 of Set 11 | paamiut
# Processing Record 19 of Set 11 | doha
# Processing Record 20 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 11 | fairbanks
# Processing Record 22 of Set 11 | xixiang
# Processing Record 23 of Set 11 | ugoofaaru
# Processing Record 24 of Set 11 | najran
# Processing Record 25 of Set 11 | tokur
# Processing Record 26 of Set 11 | talca
# Processing Record 27 of Set 11 | zhangjiakou
# Processing Record 28 of Set 11 | floro
# Processing Record 29 of Set 11 | souillac
# Processing Record 30 of Set 11 | tyukalinsk
# Processing Record 31 of Set 11 | ibimirim
# Processing Record 32 of Set 11 | tambacounda
# Processing Record 33 of Set 11 | hamilton
# Processing Record 34 of Set 11 | marawi
# Processing Record 35 of Set 11 | lebyazhye
# Processing Record 36 of Set 11 | otane
# Processing Record 37 of Set 11 | moron
# Processing Record 38 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 11 | arandis
# Processing Record 40 of Set 11 | mecca
# Processing Record 41 of Set 11 | ovsyanka
# Processing Record 42 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 11 | waipawa
# Processing Record 44 of Set 11 | krasnokamsk
# Processing Record 45 of Set 11 | kosh-agach
# Processing Record 46 of Set 11 | caarapo
# Processing Record 47 of Set 11 | kutum
# Processing Record 48 of Set 11 | izumo
# Processing Record 49 of Set 11 | nelson bay
# Processing Record 50 of Set 11 | mitu
# Processing Record 1 of Set 12 | bathsheba
# Processing Record 2 of Set 12 | tecpan
# Processing Record 3 of Set 12 | narnaund
# Processing Record 4 of Set 12 | qasigiannguit
# Processing Record 5 of Set 12 | gariaband
# Processing Record 6 of Set 12 | tabas
# Processing Record 7 of Set 12 | bilibino
# Processing Record 8 of Set 12 | coquimbo
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | mattru
# Processing Record 11 of Set 12 | gornyak
# Processing Record 12 of Set 12 | tianpeng
# Processing Record 13 of Set 12 | miles city
# Processing Record 14 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 12 | kalayaan
# Processing Record 16 of Set 12 | kattivakkam
# Processing Record 17 of Set 12 | ostrovnoy
# Processing Record 18 of Set 12 | luanda
# Processing Record 19 of Set 12 | marsh harbour
# Processing Record 20 of Set 12 | laguna
# Processing Record 21 of Set 12 | gondar
# Processing Record 22 of Set 12 | pio xii
# Processing Record 23 of Set 12 | jian
# Processing Record 24 of Set 12 | prince rupert
# Processing Record 25 of Set 12 | aykhal
# Processing Record 26 of Set 12 | kruisfontein
# Processing Record 27 of Set 12 | port keats
# Processing Record 28 of Set 12 | paredon
# Processing Record 29 of Set 12 | same
# Processing Record 30 of Set 12 | ayagoz
# Processing Record 31 of Set 12 | lamu
# Processing Record 32 of Set 12 | joshimath
# Processing Record 33 of Set 12 | walvis bay
# Processing Record 34 of Set 12 | puerto colombia
# Processing Record 35 of Set 12 | hammerfest
# Processing Record 36 of Set 12 | anadyr
# Processing Record 37 of Set 12 | shingu
# Processing Record 38 of Set 12 | dwarka
# Processing Record 39 of Set 12 | tocache
# Processing Record 40 of Set 12 | pringsewu
# Processing Record 41 of Set 12 | antigonish
# Processing Record 42 of Set 12 | laguna de perlas
# Processing Record 43 of Set 12 | roma
# Processing Record 44 of Set 12 | khorixas
# Processing Record 45 of Set 12 | nadym
# Processing Record 46 of Set 12 | kolyvan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7818e16cca2b62a3109d0a324d8b034e&q=kolyvan'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Upernavik  72.7868  -56.1549     45.52        74         100
# 1       Srednekolymsk  67.4500  153.6833     43.86        57         100
# 2            Hermanus -34.4187   19.2345     53.19        75          29
# 3                Lasa  46.6166   10.7002     79.68        89          23
# 4             Rikitea -23.1203 -134.9692     74.05        74           0
# ..                ...      ...       ...       ...       ...         ...
# 548  Laguna De Perlas  12.3429  -83.6712     86.09        88         100
# 549              Roma  43.2128  -75.4557     87.82        62          20
# 550          Khorixas -20.3667   14.9667     58.28        46           0
# 551             Nadym  65.5333   72.5167     60.71        56         100
# 552           Kolyvan  55.3053   82.7391     53.22        88          91
#
#      Wind Speed Country                 Date
# 0          3.76      GL  2022-07-19 20:41:26
# 1          8.55      RU  2022-07-19 20:41:27
# 2          5.10      ZA  2022-07-19 20:41:27
# 3          2.42      IT  2022-07-19 20:41:27
# 4          9.78      PF  2022-07-19 20:41:28
# ..          ...     ...                  ...
# 548       14.52      NI  2022-07-19 20:55:29
# 549       13.80      US  2022-07-19 20:50:53
# 550        4.25      NA  2022-07-19 20:55:29
# 551        9.08      RU  2022-07-19 20:55:30
# 552        4.85      RU  2022-07-19 20:55:30
#
# [553 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
